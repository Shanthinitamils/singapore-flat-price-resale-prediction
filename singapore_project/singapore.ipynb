# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv(r'C:\Users\HP\Desktop\New folder\singapore90to99.csv')
df1.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price
# 0            31.0   IMPROVED                 1977          9000
# 1            31.0   IMPROVED                 1977          6000
# 2            31.0   IMPROVED                 1977          8000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287196 entries, 0 to 287195
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                287196 non-null  object
#  1   town                 287196 non-null  object
#  2   flat_type            287196 non-null  object
#  3   block                287196 non-null  object
#  4   street_name          287196 non-null  object
#  5   storey_range         287196 non-null  object
#  6   floor_area_sqm       287196 non-null  float64
#  7   flat_model           287196 non-null  object
#  8   lease_commence_date  287196 non-null  int64
#  9   resale_price         287196 non-null  int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 21.9+ MB

# %%
df2=pd.read_csv(r'C:\Users\HP\Desktop\New folder\singapore99to20.csv')
df2.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2  2000-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            69.0        Improved                 1986      147000.0
# 1            61.0        Improved                 1986      144000.0
# 2            73.0  New Generation                 1976      159000.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369651 entries, 0 to 369650
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                369651 non-null  object
#  1   town                 369651 non-null  object
#  2   flat_type            369651 non-null  object
#  3   block                369651 non-null  object
#  4   street_name          369651 non-null  object
#  5   storey_range         369651 non-null  object
#  6   floor_area_sqm       369651 non-null  float64
#  7   flat_model           369651 non-null  object
#  8   lease_commence_date  369651 non-null  int64
#  9   resale_price         369651 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 28.2+ MB

# %%
df3 = pd.read_csv(r'C:\Users\HP\Desktop\New folder\singapore2012to14.csv')
df3.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 ROOM   172  ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 ROOM   510  ANG MO KIO AVE 8     01 TO 05
# 2  2012-03  ANG MO KIO    3 ROOM   610  ANG MO KIO AVE 4     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            45.0        Improved                 1986      250000.0
# 1            44.0        Improved                 1980      265000.0
# 2            68.0  New Generation                 1980      315000.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52203 entries, 0 to 52202
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                52203 non-null  object
#  1   town                 52203 non-null  object
#  2   flat_type            52203 non-null  object
#  3   block                52203 non-null  object
#  4   street_name          52203 non-null  object
#  5   storey_range         52203 non-null  object
#  6   floor_area_sqm       52203 non-null  float64
#  7   flat_model           52203 non-null  object
#  8   lease_commence_date  52203 non-null  int64
#  9   resale_price         52203 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 4.0+ MB

# %%
df4 = pd.read_csv(r'C:\Users\HP\Desktop\New folder\singapore2015to17.csv')
df4.head(3)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37153 entries, 0 to 37152
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                37153 non-null  object
#  1   town                 37153 non-null  object
#  2   flat_type            37153 non-null  object
#  3   block                37153 non-null  object
#  4   street_name          37153 non-null  object
#  5   storey_range         37153 non-null  object
#  6   floor_area_sqm       37153 non-null  float64
#  7   flat_model           37153 non-null  object
#  8   lease_commence_date  37153 non-null  int64
#  9   remaining_lease      37153 non-null  int64
#  10  resale_price         37153 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 3.1+ MB

# %%
df5 = pd.read_csv(r'C:\Users\HP\Desktop\New folder\singapore2017totill.csv')
df5.head(3)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0

# %%
df5['remaining_lease'] = df5['remaining_lease'].str.split(' ').str[0].astype('int64')

# %%
df5.head(3)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            44.0        Improved                 1979               61
# 1            67.0  New Generation                 1978               60
# 2            67.0  New Generation                 1980               62
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181077 entries, 0 to 181076
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                181077 non-null  object
#  1   town                 181077 non-null  object
#  2   flat_type            181077 non-null  object
#  3   block                181077 non-null  object
#  4   street_name          181077 non-null  object
#  5   storey_range         181077 non-null  object
#  6   floor_area_sqm       181077 non-null  float64
#  7   flat_model           181077 non-null  object
#  8   lease_commence_date  181077 non-null  int64
#  9   remaining_lease      181077 non-null  int64
#  10  resale_price         181077 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 15.2+ MB

# %%
df_combined = pd.concat([df1,df2,df3,df4,df5], ignore_index=True)
df_combined.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
# 2            31.0   IMPROVED                 1977        8000.0
#
#    remaining_lease
# 0              NaN
# 1              NaN
# 2              NaN

# %%
df_combined.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
df_combined[['year', 'month']] = df_combined['month'].str.split('-',expand=True)

# %%
df_combined.head(3)
# Out:
#   month        town flat_type block       street_name storey_range  \
# 0    01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1    01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2    01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
# 2            31.0   IMPROVED                 1977        8000.0
#
#    remaining_lease  year
# 0              NaN  1990
# 1              NaN  1990
# 2              NaN  1990

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927280 entries, 0 to 927279
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                927280 non-null  object
#  1   town                 927280 non-null  object
#  2   flat_type            927280 non-null  object
#  3   block                927280 non-null  object
#  4   street_name          927280 non-null  object
#  5   storey_range         927280 non-null  object
#  6   floor_area_sqm       927280 non-null  float64
#  7   flat_model           927280 non-null  object
#  8   lease_commence_date  927280 non-null  int64
#  9   resale_price         927280 non-null  float64
#  10  remaining_lease      218230 non-null  float64
#  11  year                 927280 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 84.9+ MB

# %%
df_combined['year'] = pd.to_numeric(df_combined['year'])
df_combined['month'] = pd.to_numeric(df_combined['month'])
df_combined['floor_area_sqm'] = pd.to_numeric(df_combined['floor_area_sqm'])
df_combined['resale_price'] = pd.to_numeric(df_combined['resale_price'])

# %%
df_combined['remaining_lease'].fillna(99-(df_combined['year']-df_combined['lease_commence_date']),inplace=True)
df_combined.head(2)
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
#
#    remaining_lease  year
# 0             86.0  1990
# 1             86.0  1990

# %%
df_combined.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# year                   0
# dtype: int64

# %%
df_combined['flat_model'].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'DBSS', 'Type S1',
#        'Type S2', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
df_combined['flat_model']=df_combined['flat_model'].str.upper()

# %%
df_combined['flat_model'].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'ADJOINED FLAT', 'PREMIUM MAISONETTE',
#        'MODEL A2', 'DBSS', 'TYPE S1', 'TYPE S2', 'PREMIUM APARTMENT LOFT',
#        '3GEN'], dtype=object)

# %%
df_combined['years_holding'].min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'years_holding'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_combined['years_holding'].max()
# Out:
# 58

# %%
import datetime

# Adding a new column 'price_per_sqm'
df_combined['price_per_sqm'] = df_combined['resale_price'] / df_combined['floor_area_sqm']

# %%
df_combined['years_holding'] = df_combined['year'] - df_combined['lease_commence_date']

# %%
df_combined['years_holding']=df_combined['years_holding'].apply(lambda x:0 if x<=0 else x)

# %%
df_combined['current_remaining_lease'] = df_combined['remaining_lease'] - (2024 - df_combined['year'])

# %%
import time
current_year = datetime.datetime.now().year
df_combined['age_of_property'] = current_year - df_combined['lease_commence_date']

# %%
df_combined.head(3)
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
# 2            31.0   IMPROVED                 1977        8000.0
#
#    remaining_lease  year  price_per_sqm  years_holding  \
# 0             86.0  1990     290.322581             13
# 1             86.0  1990     193.548387             13
# 2             86.0  1990     258.064516             13
#
#    current_remaining_lease  age_of_property
# 0                     52.0               47
# 1                     52.0               47
# 2                     52.0               47

# %%
df_combined['storey_range'].unique()
# Out:
# array(['10 TO 12', '04 TO 06', '07 TO 09', '01 TO 03', '13 TO 15',
#        '19 TO 21', '16 TO 18', '25 TO 27', '22 TO 24', '28 TO 30',
#        '31 TO 33', '40 TO 42', '37 TO 39', '34 TO 36', '06 TO 10',
#        '01 TO 05', '11 TO 15', '16 TO 20', '21 TO 25', '26 TO 30',
#        '36 TO 40', '31 TO 35', '46 TO 48', '43 TO 45', '49 TO 51'],
#       dtype=object)

# %%
# Split the 'storey_range' column into two separate columns
df_combined[['lower_storey', 'upper_storey']] = df_combined['storey_range'].str.split(' TO ', expand=True)

# Convert the new columns to integer type for further analysis if necessary
df_combined['lower_storey'] = df_combined['lower_storey'].astype(int)
df_combined['upper_storey'] = df_combined['upper_storey'].astype(int)

# %%
df_combined.head()
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            31.0        IMPROVED                 1977        9000.0
# 1            31.0        IMPROVED                 1977        6000.0
# 2            31.0        IMPROVED                 1977        8000.0
# 3            31.0        IMPROVED                 1977        6000.0
# 4            73.0  NEW GENERATION                 1976       47200.0
#
#    remaining_lease  year  price_per_sqm  years_holding  \
# 0             86.0  1990     290.322581             13
# ...

# %%
df_combined.describe().T
# Out:
#                             count           mean            std          min  \
# month                    927280.0       6.550590       3.413370     1.000000
# floor_area_sqm           927280.0      95.690987      25.825050    28.000000
# lease_commence_date      927280.0    1988.276343      10.663145  1966.000000
# resale_price             927280.0  320783.208689  170450.043194  5000.000000
# remaining_lease          927280.0      81.003297      10.789455    41.000000
# year                     927280.0    2006.170835       9.322297  1990.000000
# price_per_sqm            927280.0    3317.461278    1531.368906   161.290323
# years_holding            927280.0      17.894552      10.715932     0.000000
# current_remaining_lease  927280.0      63.174132      10.611832    40.000000
# age_of_property          927280.0      35.723657      10.663145     2.000000
# lower_storey             927280.0       6.682099       4.821780     1.000000
# ...

# %%
df_combined.head()
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            31.0        IMPROVED                 1977        9000.0
# 1            31.0        IMPROVED                 1977        6000.0
# 2            31.0        IMPROVED                 1977        8000.0
# 3            31.0        IMPROVED                 1977        6000.0
# 4            73.0  NEW GENERATION                 1976       47200.0
#
#    remaining_lease  year  price_per_sqm  years_holding  \
# 0             86.0  1990     290.322581             13
# ...

# %%
df_resale=df_combined.copy()
df_resale.head(3)
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
# 2            31.0   IMPROVED                 1977        8000.0
#
#    remaining_lease  year  price_per_sqm  years_holding  \
# 0             86.0  1990     290.322581             13
# 1             86.0  1990     193.548387             13
# 2             86.0  1990     258.064516             13
#
#    current_remaining_lease  age_of_property  lower_storey  upper_storey
# 0                     52.0               47            10            12
# ...

# %%
from scipy.stats import skew

for col in['lower_storey','upper_storey','floor_area_sqm','remaining_lease','price_per_sqm','years_holding','current_remaining_lease','age_of_property','resale_price']:
   print(f'Skewness of {col}: {skew(df_resale[col])}')
# Out:
# Skewness of lower_storey: 1.352043802261439
# Skewness of upper_storey: 1.3527383496536816
# Skewness of floor_area_sqm: 0.36612023804047483
# Skewness of remaining_lease: -0.7162595725558664
# Skewness of price_per_sqm: 1.072020401197394
# Skewness of years_holding: 0.6970993280356869
# Skewness of current_remaining_lease: 0.6273971399267538
# Skewness of age_of_property: -0.6469454087638171
# Skewness of resale_price: 0.9410954370293994

# %%
def plot(df_resale, column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=df_resale, x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=df_resale, x=column, kde=True, bins=50)
    plt.title(f'Distribution Plot for {column}')

    plt.subplot(1,3,3)
    sns.violinplot(data=df_resale, x=column)
    plt.title(f'Violin Plot for {column}')
    plt.show()

# %%
for i in ['floor_area_sqm','remaining_lease','price_per_sqm','years_holding','current_remaining_lease','age_of_property','resale_price']:
    plot(df_resale, i)

# %%
sns.boxplot(data = df_combined)
# Out:
# <Axes: >

# %%
df_final = df_resale.copy()
# Apply log transformation (add a small constant to avoid log(0))
df_final['lower_storey_log'] = np.log1p(df_final['lower_storey'])
df_final['upper_storey_log'] = np.log1p(df_final['upper_storey'])
df_final['resale_price_log'] = np.log1p(df_final['resale_price'])
df_final['price_per_sqm_log'] = np.log1p(df_final['price_per_sqm'])

# %%
def plot(df_final, column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=df_final, x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=df_final, x=column, kde=True, bins=50)
    plt.title(f'Distribution Plot for {column}')

    plt.subplot(1,3,3)
    sns.violinplot(data=df_final, x=column)
    plt.title(f'Violin Plot for {column}')
    plt.show()

# %%
for i in ['lower_storey_log','upper_storey_log','floor_area_sqm','remaining_lease','price_per_sqm_log','years_holding','current_remaining_lease','age_of_property','resale_price_log']:
    plot(df_final, i)

# %%
# To reduce the outliers by using clip technique
def outlier(df, column):
    iqr = df[column].quantile(0.75) - df[column].quantile(0.25)
    upper_threshold = df[column].quantile(0.75) + (1.5*iqr)
    lower_threshold = df[column].quantile(0.25) - (1.5*iqr)
    df[column] = df[column].clip(lower_threshold, upper_threshold)

# %%
outlier(df_final, 'floor_area_sqm')
outlier(df_final, 'years_holding')
outlier(df_final, 'lower_storey_log')
outlier(df_final, 'upper_storey_log')
outlier(df_final, 'resale_price_log')
outlier(df_final, 'price_per_sqm_log')
df_final
# Out:
#         month        town         flat_type block       street_name  \
# 0           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4           1  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...       ...         ...               ...   ...               ...
# 927275      4      YISHUN         EXECUTIVE   836      YISHUN ST 81
# 927276      5      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 927277      6      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 927278      2      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
# 927279      3      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
df_finals=df_final.copy()
df_finals.head(3)
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  ...  \
# 0            31.0   IMPROVED                 1977        9000.0  ...
# 1            31.0   IMPROVED                 1977        6000.0  ...
# 2            31.0   IMPROVED                 1977        8000.0  ...
#
#    price_per_sqm  years_holding  current_remaining_lease  age_of_property  \
# 0     290.322581             13                     52.0               47
# 1     193.548387             13                     52.0               47
# 2     258.064516             13                     52.0               47
#
#    lower_storey  upper_storey  lower_storey_log  upper_storey_log  \
# ...

# %%
# Outliers Treatment

# Define the function to remove outliers using the IQR method
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q2 = df[column].quantile(0.75)
    IQR = Q2 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q2 + 1.5 * IQR
    df = df[(df[column] >= lower_limit) & (df[column] <= upper_limit)]
    return df

# Apply the IQR method to continuous variables
continuous_var = ['floor_area_sqm','years_holding','lower_storey_log','upper_storey_log','resale_price_log','price_per_sqm_log']
for col in continuous_var:
    df_finals = remove_outliers_iqr(df_finals, col)

# Check the shape of the dataframe after outlier removal
print(f"Reshaped Dataframe after Outlier Treatment: {df_finals.shape}")

# Reset the index
df_finals.reset_index(drop=True, inplace=True)
# Out:
# Reshaped Dataframe after Outlier Treatment: (927280, 22)

# %%
def plot(df_finals, column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=df_finals, x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=df_finals, x=column, kde=True, bins=50)
    plt.title(f'Distribution Plot for {column}')

    plt.subplot(1,3,3)
    sns.violinplot(data=df_finals, x=column)
    plt.title(f'Violin Plot for {column}')
    plt.show()

# %%
for i in ['lower_storey_log','upper_storey_log','floor_area_sqm','remaining_lease','price_per_sqm_log','years_holding','current_remaining_lease','age_of_property','resale_price_log']:
    plot(df_finals, i)

# %%
df_finals['remaining_lease'].unique()
# Out:
# array([ 86.,  85.,  87.,  88.,  93.,  89.,  94.,  90.,  91.,  95.,  81.,
#         92.,  82.,  78.,  84.,  80.,  83.,  76.,  79.,  77.,  97.,  96.,
#         98.,  75., 100.,  99.,  74.,  73.,  72., 101.,  71.,  70.,  69.,
#         68.,  67.,  66.,  65.,  64.,  63.,  62.,  61.,  60.,  59.,  58.,
#         57.,  56.,  55.,  54.,  53.,  52.,  51.,  50.,  49.,  48.,  47.,
#         46.,  45.,  44.,  43.,  42.,  41.])

# %%
df_finals['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
df_finals['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              352414
# 3 ROOM              296021
# 5 ROOM              195475
# EXECUTIVE            69688
# 2 ROOM               11835
# 1 ROOM                1304
# MULTI GENERATION       279
# MULTI-GENERATION       264
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
df_finals["flat_type"]= OrdinalEncoder().fit_transform(df_finals[["flat_type"]])
df_finals['flat_type'].unique()
# Out:
# array([0., 2., 3., 4., 1., 5., 6., 7.])

# %%
df_finals['flat_type'].value_counts()
# Out:
# flat_type
# 3.0    352414
# 2.0    296021
# 4.0    195475
# 5.0     69688
# 1.0     11835
# 0.0      1304
# 6.0       279
# 7.0       264
# Name: count, dtype: int64

# %%
df_finals['flat_model'].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'ADJOINED FLAT', 'PREMIUM MAISONETTE',
#        'MODEL A2', 'DBSS', 'TYPE S1', 'TYPE S2', 'PREMIUM APARTMENT LOFT',
#        '3GEN'], dtype=object)

# %%
df_finals['flat_model'].value_counts()
# Out:
# flat_model
# MODEL A                   265199
# IMPROVED                  241861
# NEW GENERATION            189000
# SIMPLIFIED                 57554
# PREMIUM APARTMENT          46795
# STANDARD                   42550
# APARTMENT                  35497
# MAISONETTE                 29672
# MODEL A2                   10140
# DBSS                        3306
# MODEL A-MAISONETTE          2077
# ADJOINED FLAT               1250
# TERRACE                      694
# MULTI GENERATION             543
# TYPE S1                      437
# TYPE S2                      217
# 2-ROOM                       136
# IMPROVED-MAISONETTE          126
# PREMIUM APARTMENT LOFT       108
# PREMIUM MAISONETTE            86
# 3GEN                          32
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
df_finals["flat_model"]= OrdinalEncoder().fit_transform(df_finals[["flat_model"]])
df_finals['flat_model'].unique()
# Out:
# array([ 5., 12.,  8., 17., 16.,  9.,  3.,  7., 18.,  0.,  6., 11., 13.,
#         2., 15., 10.,  4., 19., 20., 14.,  1.])

# %%
df_finals['flat_model'].value_counts()
# Out:
# flat_model
# 8.0     265199
# 5.0     241861
# 12.0    189000
# 16.0     57554
# 13.0     46795
# 17.0     42550
# 3.0      35497
# 7.0      29672
# 10.0     10140
# 4.0       3306
# 9.0       2077
# 2.0       1250
# 18.0       694
# 11.0       543
# 19.0       437
# 20.0       217
# 0.0        136
# 6.0        126
# 14.0       108
# 15.0        86
# 1.0         32
# Name: count, dtype: int64

# %%
df_finals['town'].value_counts()
# Out:
# town
# TAMPINES           79988
# YISHUN             70085
# JURONG WEST        66704
# BEDOK              66670
# WOODLANDS          65553
# ANG MO KIO         52082
# HOUGANG            50762
# BUKIT BATOK        44421
# CHOA CHU KANG      38340
# BUKIT MERAH        34372
# PASIR RIS          33233
# SENGKANG           32478
# TOA PAYOH          31533
# QUEENSTOWN         28783
# GEYLANG            28170
# CLEMENTI           28037
# BUKIT PANJANG      27702
# KALLANG/WHAMPOA    27188
# JURONG EAST        24794
# SERANGOON          22829
# BISHAN             21266
# PUNGGOL            20653
# SEMBAWANG          13865
# MARINE PARADE       8041
# CENTRAL AREA        7150
# BUKIT TIMAH         2517
# LIM CHU KANG          64
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
df_finals["town"]= OrdinalEncoder().fit_transform(df_finals[["town"]])
df_finals['town'].unique()
# Out:
# array([ 0.,  1.,  2.,  3.,  4.,  6.,  7.,  8.,  9., 10., 11., 12., 13.,
#        14., 16., 19., 21., 22., 23., 24., 25., 26., 15., 20.,  5., 17.,
#        18.])

# %%
df_finals['town'].value_counts()
# Out:
# town
# 23.0    79988
# 26.0    70085
# 13.0    66704
# 1.0     66670
# 25.0    65553
# 0.0     52082
# 11.0    50762
# 3.0     44421
# 8.0     38340
# 4.0     34372
# 17.0    33233
# 21.0    32478
# 24.0    31533
# 19.0    28783
# 10.0    28170
# 9.0     28037
# 5.0     27702
# 14.0    27188
# 12.0    24794
# 22.0    22829
# 2.0     21266
# 18.0    20653
# 20.0    13865
# 16.0     8041
# 7.0      7150
# 6.0      2517
# 15.0       64
# Name: count, dtype: int64

# %%
df_selected = df_finals[['month','town','flat_type','lower_storey_log','upper_storey_log','floor_area_sqm','flat_model',
                          'lease_commence_date','resale_price_log','remaining_lease','year','price_per_sqm_log','years_holding',
                          'current_remaining_lease','age_of_property']]

# %%
# Calculate correlation coefficients
correlation = df_selected.corr()

# Absolute correlation values with the target column
correlation_with_target = correlation['resale_price_log'].abs().sort_values(ascending=False)

print("Correlation with target column:")
print(correlation_with_target)
# Out:
# Correlation with target column:
# resale_price_log           1.000000
# price_per_sqm_log          0.883551
# year                       0.688586
# flat_type                  0.602380
# floor_area_sqm             0.588774
# lease_commence_date        0.534369
# age_of_property            0.534369
# current_remaining_lease    0.528802
# flat_model                 0.261071
# upper_storey_log           0.152291
# lower_storey_log           0.137663
# town                       0.084179
# remaining_lease            0.074856
# years_holding              0.067347
# month                      0.009755
# Name: resale_price_log, dtype: float64

# %%
# Calculate the correlation matrix
correlation_matrix = df_selected.corr()

# Plot the heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plot the heatmap for the top correlations with 'resale_price'
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix[['resale_price_log']].sort_values(by='resale_price_log', ascending=False), annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.5)
plt.title('Correlation Heatmap with Resale Price')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor


from sklearn import metrics
import numpy as np
from sklearn.metrics import r2_score

# %%
df_finaly=df_finals.copy()
df_finaly.head(3)
# Out:
#    month  town  flat_type block       street_name storey_range  \
# 0      1   0.0        0.0   309  ANG MO KIO AVE 1     10 TO 12
# 1      1   0.0        0.0   309  ANG MO KIO AVE 1     04 TO 06
# 2      1   0.0        0.0   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm  flat_model  lease_commence_date  resale_price  ...  \
# 0            31.0         5.0                 1977        9000.0  ...
# 1            31.0         5.0                 1977        6000.0  ...
# 2            31.0         5.0                 1977        8000.0  ...
#
#    price_per_sqm  years_holding  current_remaining_lease  age_of_property  \
# 0     290.322581             13                     52.0               47
# 1     193.548387             13                     52.0               47
# 2     258.064516             13                     52.0               47
#
#    lower_storey  upper_storey  lower_storey_log  upper_storey_log  \
# ...

# %%
df_finals.head(1)
# Out:
#    month  town  flat_type block       street_name storey_range  \
# 0      1   0.0        0.0   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm  flat_model  lease_commence_date  resale_price  ...  \
# 0            31.0         5.0                 1977        9000.0  ...
#
#    price_per_sqm  years_holding  current_remaining_lease  age_of_property  \
# 0     290.322581             13                     52.0               47
#
#    lower_storey  upper_storey  lower_storey_log  upper_storey_log  \
# 0            10            12          2.397895          2.564949
#
#    resale_price_log  price_per_sqm_log
# 0         11.011268            6.82906
#
# [1 rows x 22 columns]

# %%
df_finaly.drop(columns=['month','block','street_name','storey_range','resale_price','price_per_sqm','lower_storey','upper_storey'], inplace=True)

# %%
df_finaly.shape
# Out:
# (927280, 14)

# %%
def best_ML_algorithm(df, algorithms):
    x=df.drop(columns=['resale_price_log'],axis=1)
    y=df['resale_price_log']
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42) # Split the data for train and test the model

    results = {}

# choosing the best algorith which suits for data
    for algorithm in algorithms:
        model = algorithm().fit(x_train, y_train)
        y_pred = model.predict(x_test)
        MAE = metrics.mean_absolute_error(y_test, y_pred)
        MSE = metrics.mean_squared_error(y_test, y_pred)
        RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
        r2 = metrics.r2_score(y_test, y_pred)

        results[algorithm.__name__] = {
            'Mean Absolute Error': MAE,
            'Mean Squared Error': MSE,
            'Root Mean Squared Error': RMSE,
            'R² score': r2
        }

        print(f"**Evaluation Metrics for {algorithm.__name__}:**")
        print(f"Mean Absolute Error: {MAE}")
        print(f"Mean Squared Error: {MSE}")
        print(f"Root Mean Squared Error: {RMSE}")
        print(f"R² score: {r2}")
        print()

    best_algorithm = max(results.items(), key=lambda item: item[1]['R² score'])[0]

    return best_algorithm, results

#algorithm used for checking
algorithms = [
    LinearRegression, DecisionTreeRegressor, ExtraTreesRegressor, RandomForestRegressor,
    GradientBoostingRegressor, XGBRegressor
]

best_algorithm, results = best_ML_algorithm(df_finaly, algorithms)

results_df = pd.DataFrame(results).transpose()

print("**Evaluation Metrics for All Algorithms:**")
print(results_df.to_string())

print("**Best Algorithm:**", best_algorithm)
# Out:
# **Evaluation Metrics for LinearRegression:**
# Mean Absolute Error: 0.026316708360196065
# Mean Squared Error: 0.0014721853030348192
# Root Mean Squared Error: 0.0383690670076146
# R² score: 0.9942534738811126
#
# **Evaluation Metrics for DecisionTreeRegressor:**
# Mean Absolute Error: 0.0003580983746615709
# Mean Squared Error: 4.561429563283963e-06
# Root Mean Squared Error: 0.002135750351348201
# R² score: 0.9999821949220178
#
# **Evaluation Metrics for ExtraTreesRegressor:**
# Mean Absolute Error: 0.00034316724180631837
# Mean Squared Error: 3.269388426232589e-06
# Root Mean Squared Error: 0.0018081450235621559
# R² score: 0.999987238273643
#
# **Evaluation Metrics for RandomForestRegressor:**
# Mean Absolute Error: 0.00026709753164244724
# Mean Squared Error: 1.5575414511977634e-06
# Root Mean Squared Error: 0.0012480150043960862
# R² score: 0.9999939202948079
#
# **Evaluation Metrics for GradientBoostingRegressor:**
# Mean Absolute Error: 0.016039100732226044
# ...

# %%
# By using the parameters getting from gridsearchCV we train a model by the params

x=df_finaly.drop(columns=['resale_price_log'],axis=1)
y=df_finaly['resale_price_log']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42) 

model=RandomForestRegressor(n_estimators=150,random_state=42,max_depth=20)
model.fit(x_train,y_train)

y_pred=model.predict(x_test)

MAE=metrics.mean_absolute_error(y_test,y_pred)
MSE=metrics.mean_squared_error(y_test,y_pred)
RMSE=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
r2=metrics.r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {MAE}")
print(f"Mean Squared Error : {MSE}")
print(f"Root Mean Squared Error: {RMSE}")
print(f"R-Squared: {r2}")
# Out:
# Mean Absolute Error: 0.0002623733226498867
# Mean Squared Error : 1.5492735832349374e-06
# Root Mean Squared Error: 0.0012446981896166386
# R-Squared: 0.9999939525675925

# %%
df_finaly.head(1)
# Out:
#    town  flat_type  floor_area_sqm  flat_model  lease_commence_date  \
# 0   0.0        3.0            81.0        12.0                 1977
#
#    remaining_lease  year  years_holding  current_remaining_lease  \
# 0             86.0  1990             13                     52.0
#
#    age_of_property  lower_storey_log  upper_storey_log  resale_price_log  \
# 0               47          1.609438           1.94591         11.289794
#
#    price_per_sqm_log
# 0           6.896345

# %%
# Checking the accuracy manually
user_data = np.array([[0.0,3.0,81.0,12.0,1977,86.0,1990,13,52.0,47,1.609438,1.954591,6.896345]])

y_pred = model.predict(user_data)
y_pred[0]
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 11.290785900662183

# %%
print("Training features:")
print(x_train.columns)

print("\nTest features:")
print(x_test.columns)
# Out:
# Training features:
# Index(['town', 'flat_type', 'floor_area_sqm', 'flat_model',
#        'lease_commence_date', 'remaining_lease', 'year', 'years_holding',
#        'current_remaining_lease', 'age_of_property', 'lower_storey_log',
#        'upper_storey_log', 'price_per_sqm_log'],
#       dtype='object')
#
# Test features:
# Index(['town', 'flat_type', 'floor_area_sqm', 'flat_model',
#        'lease_commence_date', 'remaining_lease', 'year', 'years_holding',
#        'current_remaining_lease', 'age_of_property', 'lower_storey_log',
#        'upper_storey_log', 'price_per_sqm_log'],
#       dtype='object')

# %%
df_combined['price_per_sqm'].min()
# Out:
# 161.29032258064515

# %%
df_combined['age_of_property'].max()
# Out:
# 58

# %%
df_finaly['current_remaining_lease'].min()
# Out:
# 41.0

# %%
df_finaly['current_remaining_lease'].max()
# Out:
# 95.0

# %%
np.expm1(y_pred[0])
# Out:
# 80080.3592935863

# %%
feature_scores = pd.Series(model.feature_importances_, index=x_train.columns).sort_values(ascending=False)
feature_scores
# Out:
# price_per_sqm_log          7.122076e-01
# floor_area_sqm             2.698118e-01
# flat_type                  1.796250e-02
# remaining_lease            2.525537e-06
# age_of_property            2.442365e-06
# flat_model                 2.270709e-06
# years_holding              1.951703e-06
# lease_commence_date        1.945605e-06
# year                       1.914419e-06
# current_remaining_lease    1.906280e-06
# town                       1.883871e-06
# upper_storey_log           6.462517e-07
# lower_storey_log           6.334305e-07
# dtype: float64

# %%
from sklearn.model_selection import cross_val_score

cross_val_scores = cross_val_score(model, x, y, cv=3, scoring='r2')
print(f"Cross-Validation R² Scores: {cross_val_scores}")
print(f"Mean R² Score: {cross_val_scores.mean()}")
# Out:
# Cross-Validation R² Scores: [0.99775418 0.99993364 0.97989733]
# Mean R² Score: 0.9925283846111886

# %%
# Pickling Regression model:

import pickle

with open('singapore_random_regression.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
x=df_finaly.drop(columns=['resale_price_log'],axis=1)
y=df_finaly['resale_price_log']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# Initialize the decision tree regressor model
decision_tree_model = DecisionTreeRegressor()

# Train the model on the training data
decision_tree_model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Make predictions on the testing data
y_pred = decision_tree_model.predict(x_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r_squared = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared (coefficient of determination):", r_squared)

# %%
y_pred=decision_tree_model.predict(x_test)

MAE=metrics.mean_absolute_error(y_test,y_pred)
MSE=metrics.mean_squared_error(y_test,y_pred)
RMSE=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
r2=metrics.r2_score(y_test,y_pred)

print(f"Mean Absolute Error: {MAE}")
print(f"Mean Squared Error : {MSE}")
print(f"Root Mean Squared Error: {RMSE}")
print(f"R-Squared: {r2}")
# Out:
# Mean Absolute Error: 0.001279641189621404
# Mean Squared Error : 0.000137744373496973
# Root Mean Squared Error: 0.011736454894770099
# R-Squared: 0.9995872568069448

# %%
import joblib

# saving the model as pickle file
joblib.dump(decision_tree_model, 'decision_tree_model.pkl')
# Out:
# ['decision_tree_model.pkl']
